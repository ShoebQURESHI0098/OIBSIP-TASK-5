# %%
Name Shoeb Qureshi
project Oasis Infobyte: Task 5
objective:The objective of this project is to develop a predictive model that estimates future sales based on 
historical data and various influencing factors such as advertising spend, marketing channels, and audience segmentation.

# %%
                              #importing liabries
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
                                               #import data set
df = pd.read_csv('Advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
                                           #Data Processing

df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
# summary statistics of data
display(df.describe())
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
df.shape
# Out:
# (200, 4)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated().any()
# Out:
# False

# %%
df.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
                                       #Exploratory Data Analysis¶

# %%
corr_matrix = df.corr()
corr_matrix
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example correlation matrix
import numpy as np
import pandas as pd

# Generating a random correlation matrix for illustration
np.random.seed(42)
data = np.random.rand(10, 10)
corr_matrix = pd.DataFrame(data).corr()

# Set figure size
plt.figure(figsize=(8, 6))

# Create heatmap with a different colormap and styling
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=1, linecolor='black', square=True, cbar_kws={"shrink": 0.75})

# Title for the diagram
plt.title("Correlation Matrix Heatmap", fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %%
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Ignore FutureWarnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Sample data
np.random.seed(42)
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(10, 100, size=5)

# Create a DataFrame
df = pd.DataFrame({'Category': categories, 'Value': values})

# Set figure size
plt.figure(figsize=(8, 6))

# Create a bar plot with a different style
sns.barplot(x='Category', y='Value', data=df, palette='viridis', edgecolor='black')

# Customize title and labels
plt.title("Category-wise Distribution", fontsize=14, fontweight='bold')
plt.xlabel("Category")
plt.ylabel("Value")

# Show grid for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample DataFrame (Replace this with your actual dataset)
import pandas as pd
import numpy as np

np.random.seed(42)
df = pd.DataFrame({
    'TV': np.random.randint(50, 300, 10),
    'Radio': np.random.randint(10, 100, 10),
    'Newspaper': np.random.randint(5, 50, 10),
    'Sales': np.random.randint(200, 500, 10)
})

# Set figure size
plt.figure(figsize=(8, 6))

# Plot all lines in a single figure
for column in ['TV', 'Radio', 'Newspaper']:
    sns.lineplot(x=df.index, y=df[column], label=column, marker='o')

# Customize the plot
plt.title("Advertising Spend vs Index", fontsize=14, fontweight='bold')
plt.xlabel("Index")
plt.ylabel("Spending")
plt.legend(title="Medium")
plt.grid(True, linestyle="--", alpha=0.6)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Sample DataFrame (Replace with actual data)
np.random.seed(42)
df = pd.DataFrame({
    'Category': ['A', 'B', 'C', 'D', 'E'],
    'Sales': np.random.randint(100, 500, 5)
})

# Define colors using seaborn palette
colors = sns.color_palette("pastel")

# Create the pie chart
plt.figure(figsize=(7, 7))
plt.pie(df['Sales'], labels=df['Category'], autopct='%1.1f%%', colors=colors, startangle=140, wedgeprops={'edgecolor': 'black'})

# Title
plt.title('Sales Distribution by Category', fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %%
                                                       #Model Building#

# %%
X = df.loc[:, df.columns != 'Sales']  # Select all columns except 'Sales'
y = df.loc[:, 'Sales']  # Select only the 'Sales' column

# %%
X.head()
# Out:
#   Category
# 0        A
# 1        B
# 2        C
# 3        D
# 4        E

# %%
y.head()
# Out:
# 0    202
# 1    448
# 2    370
# 3    206
# 4    171
# Name: Sales, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(y_true, y_pred):
    metrics = {
        "MAE": mean_absolute_error(y_true, y_pred),
        "MSE": mean_squared_error(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "R² Score": r2_score(y_true, y_pred)
    }
    return metrics

# %%
                                                  #Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model_name = "LinearRegression"

# Build a Linear Regression model
lin_reg = LinearRegression()

# Fit the model on the training data
lin_reg.fit(X_train, y_train)

# Predict using the model on the data
predictions = lin_reg.predict(X_test)

# Function call to Evaluate results of 'MAE', 'MSE', 'RMSE', 'R-squared'
evaluation_results_l = evaluate_model(y_test, predictions) # type: ignore

evaluation_results_l["Model"] = model_name


models = pd.DataFrame([evaluation_results_l])

print("Evaluation Results for", model_name)
print('-'*30)
for metric, value in evaluation_results_l.items():
    print(f"{metric}: {value}")
# Out:
# Evaluation Results for LinearRegression
# ------------------------------
# MAE: 1.6342482922482304e-13
# MSE: 2.716205868856988e-26
# RMSE: 1.6480915838802732e-13
# R² Score: 1.0
# Model: LinearRegression

# %%
                                             #Randome Forest model

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Ensure the evaluation function is defined
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

def evaluate_model(y_true, y_pred):
    metrics = {
        "MAE": mean_absolute_error(y_true, y_pred),
        "MSE": mean_squared_error(y_true, y_pred),
        "RMSE": np.sqrt(mean_squared_error(y_true, y_pred)),
        "R² Score": r2_score(y_true, y_pred)
    }
    return metrics

# Train Random Forest Model
rf_model = RandomForestRegressor(n_estimators=100, random_state=0)
rf_model.fit(X_train, y_train)

# Make predictions
y_pred = rf_model.predict(X_test)

# Evaluate model
evaluation_results_r = evaluate_model(y_test, y_pred)  # Use correct function name

# Add model name
evaluation_results_r["Model"] = "Random Forest"

# Store results in DataFrame
models = pd.DataFrame([evaluation_results_r])

# Display results
print(f"Evaluation Results for {evaluation_results_r['Model']}")
print("-" * 40)
for metric, value in evaluation_results_r.items():
    if metric != "Model":
        print(f"{metric}: {value:.4f}")
    else:
        print(f"{metric}: {value}")
# Out:
# Evaluation Results for Random Forest
# ----------------------------------------
# MAE: 214.0000
# MSE: 48005.0000
# RMSE: 219.1004
# R² Score: -18.2020
# Model: Random Forest

# %%
#Gradient Boosting Regressor MODEL

# %%
from sklearn.ensemble import GradientBoostingRegressor
import pandas as pd

# Train Gradient Boosting Model
gb_model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=0)
gb_model.fit(X_train, y_train)

# Make predictions
y_pred = gb_model.predict(X_test)

# Evaluate model
evaluation_results_gb = evaluate_model(y_test, y_pred)  # Use correct function

# Add model name
evaluation_results_gb["Model"] = "Gradient Boosting"

# Convert results to DataFrame
evaluation_df = pd.DataFrame([evaluation_results_gb])

# Display results
print(f"Evaluation Results for {evaluation_results_gb['Model']}")
print("-" * 40)
for metric, value in evaluation_results_gb.items():
    if isinstance(value, (int, float)):  # Check if the value is numeric before formatting
        print(f"{metric}: {value:.4f}")
    else:
        print(f"{metric}: {value}")  # Print string values without formatting
# Out:
# Evaluation Results for Gradient Boosting
# ----------------------------------------
# MAE: 182.0726
# MSE: 35650.4268
# RMSE: 188.8132
# R² Score: -13.2602
# Model: Gradient Boosting

# %%
                                  #Decision Tree Regressor Model

# %%
from sklearn.tree import DecisionTreeRegressor
import pandas as pd

# Initialize Decision Tree Regressor
dt_model = DecisionTreeRegressor(max_depth=5, random_state=0)

# Train the model
dt_model.fit(X_train, y_train)

# Make predictions
y_pred = dt_model.predict(X_test)

# Evaluate model performance
evaluation_results_dt = evaluate_model(y_test, y_pred)  # Assuming evaluate_model() function is defined

# Add model name
evaluation_results_dt["Model"] = "Decision Tree Regressor"

# Store results in DataFrame
evaluation_df = pd.DataFrame([evaluation_results_dt])

# Display results
print(f"Evaluation Results for {evaluation_results_dt['Model']}")
print("-" * 40)
for metric, value in evaluation_results_dt.items():
    if isinstance(value, (int, float)):
        print(f"{metric}: {value:.4f}")
    else:
        print(f"{metric}: {value}")
# Out:
# Evaluation Results for Decision Tree Regressor
# ----------------------------------------
# MAE: 150.0000
# MSE: 25000.0000
# RMSE: 158.1139
# R² Score: -9.0000
# Model: Decision Tree Regressor

# %%
import pandas as pd

# Create a list of model results with a fallback for missing keys
model_results = [
    {"Model": "Linear Regression", "R² Score": evaluation_results_l.get("R² Score", "N/A")},
    {"Model": "Random Forest Regressor", "R² Score": evaluation_results_r.get("R² Score", "N/A")},
    {"Model": "Gradient Boosting Regressor", "R² Score": evaluation_results_gb.get("R² Score", "N/A")},
    {"Model": "Decision Tree Regressor", "R² Score": evaluation_results_dt.get("R² Score", "N/A")}
]

# Remove entries with "N/A" (if any)
filtered_results = [res for res in model_results if res["R² Score"] != "N/A"]

# Sort by R² Score in descending order (handling cases where values are not numeric)
sorted_results = sorted(filtered_results, key=lambda x: x["R² Score"] if isinstance(x["R² Score"], (int, float)) else -1, reverse=True)

# Convert results to DataFrame
results_df = pd.DataFrame(sorted_results)

# Display results
print("Sorted Model Results (Higher R² Score is better):")
print("-" * 50)
print(results_df)
# Out:
# Sorted Model Results (Higher R² Score is better):
# --------------------------------------------------
#                          Model   R² Score
# 0            Linear Regression   1.000000
# 1      Decision Tree Regressor  -9.000000
# 2  Gradient Boosting Regressor -13.260171
# 3      Random Forest Regressor -18.202000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Ensure model_results exists before extracting values
if 'model_results' in globals():
    model_names = [model.get("Model", "Unknown") for model in model_results]
    r2_scores = [model.get("R² Score", None) for model in model_results]

    # Remove None values (if any)
    filtered_data = [(name, score) for name, score in zip(model_names, r2_scores) if score is not None]
    
    if filtered_data:  
        model_names, r2_scores = zip(*filtered_data)
    else:
        model_names, r2_scores = [], []
else:
    print("Error: 'model_results' is not defined!")

# Check if there is data to plot
if model_names and r2_scores:
    # Create DataFrame for plotting
    df_results = pd.DataFrame({"Model": model_names, "R² Score": r2_scores})

    # Set figure size
    plt.figure(figsize=(8, 5))

    # Create a horizontal bar plot using Seaborn
    sns.barplot(x="R² Score", y="Model", data=df_results, palette="coolwarm")

    # Add annotations (displaying scores on bars)
    for index, value in enumerate(df_results["R² Score"]):
        plt.text(value + 0.01, index, f"{value:.3f}", va='center')

    # Labels and title
    plt.xlabel("R² Score")
    plt.ylabel("Models")
    plt.title("Comparison of R² Scores for Different Models")

    # Show plot
    plt.show()
else:
    print("No valid data available for plotting!")
